# %% [markdown]
# # Forecasting Problem 1
#
# #### Task:
#
# Forecast the Airline prices. Prepare a document for each model explaining how many dummy variables you have created and RMSE value for each model.
# Finally which model you will use for Forecasting.

# %% [markdown]
# ## Steps:
#
# 1. Import new data set
#     - understand the dataset, look into it.
#     - perform EDA.
#     - check data info and null values.
#     - Explore and Visualize the series
# 2. Partition & Metrics
#     - Partition series
#     - Define Metrics and Predictive accuracy evaluators
# 3. Apply forecasting methods
#     - Model-driven
#         - Classical Model Based
#         - Py-caret based ML models
#     - Data-driven
#         - Moving averages & EWMA
#         - Smoothing Techniques
#         - Auto Regression Models
# 4. Evaluate and Compare Performance
#     - Compare RSME values of all models
# 5. Implement Forecasting model
# 6. Conclusion

# %% [markdown]
# ## Import new dataset

# %%
#load the Basic libraries
import pandas as pd
import numpy as np

# %%
#Load visualization libraries
import seaborn as sns
from matplotlib import pyplot as plt
import statsmodels.graphics.tsaplots as tsa_plots
from matplotlib.patches import Rectangle
# %matplotlib inline

# %%
# Load Time series Libraries
import statsmodels.formula.api as smf
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.holtwinters import SimpleExpSmoothing
from statsmodels.tsa.holtwinters import Holt
from statsmodels.tsa.holtwinters import ExponentialSmoothing

# %%
raw_data=pd.read_excel('CocaCola_Sales_Rawdata.xlsx')
raw_data.head()
# Out:
#   Quarter        Sales
# 0   Q1_86  1734.827000
# 1   Q2_86  2244.960999
# 2   Q3_86  2533.804993
# 3   Q4_86  2154.962997
# 4   Q1_87  1547.818996

# %%
raw_data.tail()
# Out:
#    Quarter   Sales
# 37   Q2_95  4936.0
# 38   Q3_95  4895.0
# 39   Q4_95  4333.0
# 40   Q1_96  4194.0
# 41   Q2_96  5253.0

# %%
data = raw_data.copy()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Quarter  42 non-null     object
#  1   Sales    42 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 800.0+ bytes

# %%
data.describe()
# Out:
#              Sales
# count    42.000000
# mean   2994.353308
# std     977.930896
# min    1547.818996
# 25%    2159.714247
# 50%    2782.376999
# 75%    3609.250000
# max    5253.000000

# %% [markdown]
# ##### Visualizing the data

# %%
viz=pd.read_excel('CocaCola_Sales_Rawdata.xlsx',header=0,index_col=0)
viz[:6]
# Out:
#                Sales
# Quarter
# Q1_86    1734.827000
# Q2_86    2244.960999
# Q3_86    2533.804993
# Q4_86    2154.962997
# Q1_87    1547.818996
# Q2_87    2104.411995

# %%
plt.figure(figsize=(20, 9))
sns.lineplot(data=viz)
plt.xticks(rotation=90)
plt.show()

# %%
sns.histplot(data=viz)
plt.show()

# %%
sns.kdeplot(data=viz, color='fuchsia')
plt.show()

# %%
data['quarters'] = data.Quarter.apply(lambda x : x.split('_')[0])
data['years'] = data.Quarter.apply(lambda x : x.split('_')[1])
data.head()
# Out:
#   Quarter        Sales quarters years
# 0   Q1_86  1734.827000       Q1    86
# 1   Q2_86  2244.960999       Q2    86
# 2   Q3_86  2533.804993       Q3    86
# 3   Q4_86  2154.962997       Q4    86
# 4   Q1_87  1547.818996       Q1    87

# %%
quater_dumies=pd.DataFrame(pd.get_dummies(data.quarters))
data=pd.concat([data,quater_dumies],axis=1)
data.head()
# Out:
#   Quarter        Sales quarters years     Q1     Q2     Q3     Q4
# 0   Q1_86  1734.827000       Q1    86   True  False  False  False
# 1   Q2_86  2244.960999       Q2    86  False   True  False  False
# 2   Q3_86  2533.804993       Q3    86  False  False   True  False
# 3   Q4_86  2154.962997       Q4    86  False  False  False   True
# 4   Q1_87  1547.818996       Q1    87   True  False  False  False

# %%
plt.figure(figsize=(12, 9))
heatmap_y_month = pd.pivot_table(data=data,values="Sales",index="quarters",columns="years",aggfunc="mean",fill_value=0)
sns.heatmap(heatmap_y_month,annot=True,fmt="g")
plt.title('Heatmap of Sales Count with Year and Quarters')
# Out:
# Text(0.5, 1.0, 'Heatmap of Sales Count with Year and Quarters')

# %%
sns.boxplot(x='quarters',y='Sales',data=data)
# Out:
# <Axes: xlabel='quarters', ylabel='Sales'>

# %%
sns.boxplot(x='years',y='Sales',data=data)
# Out:
# <Axes: xlabel='years', ylabel='Sales'>

# %% [markdown]
# ##### Seasonal Decompose plots

# %%
decompose_ts = seasonal_decompose(viz,period=12)

# %%
decompose_ts.plot()
plt.show() # there seems to be some patern in the residue

# %% [markdown]
# ##### ACF and PACF plots

# %%
tsa_plots.plot_acf(viz,lags=12)
#Autocorrelation Factor >> uptill 6 we have good corr() above +-2 SE [Standard Error]
tsa_plots.plot_pacf(viz,lags=12)
#Partial Autocorrelation Factor >> only 9 and 11 show some good corr() +-2 SE [Standard Error]
plt.show()

# %% [markdown]
# ## Preprocess data

# %% [markdown]
# #### Transformations

# %%
# adding t values >> new variable 1
data['t']= np.arange(1,data.shape[0]+1)

# %%
# adding t_sqr values >> new variable 2
data['t_sqr'] = data['t']**2

# %%
# adding log_ values >> new variable 3
data['log_sales'] = np.log(data['Sales'])

# %%
data.head()
# Out:
#   Quarter        Sales quarters years     Q1     Q2     Q3     Q4  t  t_sqr  \
# 0   Q1_86  1734.827000       Q1    86   True  False  False  False  1      1
# 1   Q2_86  2244.960999       Q2    86  False   True  False  False  2      4
# 2   Q3_86  2533.804993       Q3    86  False  False   True  False  3      9
# 3   Q4_86  2154.962997       Q4    86  False  False  False   True  4     16
# 4   Q1_87  1547.818996       Q1    87   True  False  False  False  5     25
#
#    log_sales
# 0   7.458663
# 1   7.716443
# 2   7.837477
# 3   7.675529
# 4   7.344602

# %% [markdown]
# #### Partition & Metrics

# %%
#Partition Series
train = data.iloc[:35]
test = data.iloc[35:]

# %% [markdown]
# ##### RMSE for Predictive Accuracy
# - Model with lowest RMSE is the best

# %%
#performance metrics
pfm_model_bsd = dict() # For model driven
pfm_data_bsd = dict() # For Data driven

# %% [markdown]
# ## Applying Forecasting Methods
# ### Model Driven

# %% [markdown]
# #### Classical ML Model based Methods

# %%
#Linear Model
linear_model = smf.ols('Sales~t',data=train).fit()
pred_linear =  pd.Series(linear_model.predict(pd.DataFrame(test['t'])))
rmse_linear = mean_squared_error(test.Sales, pred_linear, squared=False) #RMSE Calculation
pfm_model_bsd.update( {'Linear Model' : rmse_linear} )
rmse_linear
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# 636.5072930351143

# %%
#Exponential
Exp = smf.ols('log_sales~t',data=train).fit()
pred_Exp = pd.Series(Exp.predict(pd.DataFrame(test['t'])))
rmse_Exp = mean_squared_error(test.Sales, pred_Exp, squared=False)
pfm_model_bsd.update( {'Exponential Model' : rmse_Exp} )
rmse_Exp
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# 4515.811064811282

# %%
#Quadratic
Quad = smf.ols('Sales~t+t_sqr',data=train).fit()
pred_Quad = pd.Series(Quad.predict(test[["t","t_sqr"]]))
rmse_Quad = mean_squared_error(test.Sales,pred_Quad, squared=False)
pfm_model_bsd.update( {'Quadratic Model' : rmse_Quad} )
rmse_Quad
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# 511.811731941759

# %%
#Additive seasonality
add_sea = smf.ols('Sales~Q1+Q2+Q3+Q4',data=train).fit()
pred_add_sea = pd.Series(add_sea.predict(test[['Q1','Q2','Q3','Q4']]))
rmse_add_sea = mean_squared_error(test.Sales,pred_add_sea, squared=False)
pfm_model_bsd.update( {'Additive seasonality' : rmse_add_sea} )
rmse_add_sea
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# 1861.8704164251737

# %%
#Additive Seasonality Quadratic
add_sea_Quad = smf.ols('Sales~t+t_sqr+Q1+Q2+Q3+Q4',data=train).fit()
pred_add_sea_quad = pd.Series(add_sea_Quad.predict(test[['Q1','Q2','Q3','Q4','t','t_sqr']]))
rmse_add_sea_quad = mean_squared_error(test.Sales,pred_add_sea_quad, squared=False)
pfm_model_bsd.update( {'Additive Seasonality Quadratic' : rmse_add_sea_quad} )
rmse_add_sea_quad
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# 309.46413951632803

# %%
#Multiplicative Seasonality
Mul_sea = smf.ols('log_sales~Q1+Q2+Q3+Q4',data = train).fit()
pred_Mult_sea = pd.Series(Mul_sea.predict(test))
rmse_Mult_sea = mean_squared_error(test.Sales,pred_Mult_sea, squared=False)
pfm_model_bsd.update( {'Multiplicative Seasonality' : rmse_Mult_sea} )
rmse_Mult_sea
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# 4516.300741074347

# %%
#Multiplicative Additive Seasonality
Mul_Add_sea = smf.ols('log_sales~t+Q1+Q2+Q3+Q4',data = train).fit()
pred_Mult_add_sea = pd.Series(Mul_Add_sea.predict(test))
rmse_Mult_add_sea = mean_squared_error(test.Sales,pred_Mult_add_sea, squared=False)
pfm_model_bsd.update( {'Multiplicative Additive Seasonality ' : rmse_Mult_add_sea} )
rmse_Mult_add_sea
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# 4515.822756171213

# %%
result_model_bsd = pd.DataFrame(pfm_model_bsd.items(),columns=['MODEL', 'RMSE'])
result_model_bsd.sort_values(by=['RMSE'])
#Additive Seasonality Quadratic has the best values
# We will plot the forcasting in the evaluation part
# Out:
#                                   MODEL         RMSE
# 4        Additive Seasonality Quadratic   309.464140
# 2                       Quadratic Model   511.811732
# 0                          Linear Model   636.507293
# 3                  Additive seasonality  1861.870416
# 1                     Exponential Model  4515.811065
# 6  Multiplicative Additive Seasonality   4515.822756
# 5            Multiplicative Seasonality  4516.300741

# %% [markdown]
# ###### Model Evaluation - Additive Seasonality Quadratic

# %%
data2 = data.copy()
data2.head()
# Out:
#   Quarter        Sales quarters years     Q1     Q2     Q3     Q4  t  t_sqr  \
# 0   Q1_86  1734.827000       Q1    86   True  False  False  False  1      1
# 1   Q2_86  2244.960999       Q2    86  False   True  False  False  2      4
# 2   Q3_86  2533.804993       Q3    86  False  False   True  False  3      9
# 3   Q4_86  2154.962997       Q4    86  False  False  False   True  4     16
# 4   Q1_87  1547.818996       Q1    87   True  False  False  False  5     25
#
#    log_sales
# 0   7.458663
# 1   7.716443
# 2   7.837477
# 3   7.675529
# 4   7.344602

# %%
data2.columns.values
# Out:
# array(['Quarter', 'Sales', 'quarters', 'years', 'Q1', 'Q2', 'Q3', 'Q4',
#        't', 't_sqr', 'log_sales'], dtype=object)

# %%
data2.drop(['Quarter','Q1', 'Q2', 'Q3', 'Q4','t_sqr', 'log_sales'], axis=1, inplace=True)
data2 = data2[['t', 'years', 'quarters', 'Sales']]
data1 = data2.copy()
data3 = data2.copy()
data_fnl = data2.copy()
data2.head()
# Out:
#    t years quarters        Sales
# 0  1    86       Q1  1734.827000
# 1  2    86       Q2  2244.960999
# 2  3    86       Q3  2533.804993
# 3  4    86       Q4  2154.962997
# 4  5    87       Q1  1547.818996

# %%
data2["Predicted"] = pd.Series(add_sea_Quad.predict(data[['Q1','Q2','Q3','Q4','t','t_sqr']]))
data2.head()
# Out:
#    t years quarters        Sales    Predicted
# 0  1    86       Q1  1734.827000  1715.011163
# 1  2    86       Q2  2244.960999  2277.750192
# 2  3    86       Q3  2533.804993  2194.873446
# 3  4    86       Q4  2154.962997  1919.651866
# 4  5    87       Q1  1547.818996  1703.261332

# %%
# add a date column in the dataset
data2['Date'] = pd.date_range(start='1986-01-01', end = '1996-07-01', freq = 'Q')
data2.head()
# Out:
#    t years quarters        Sales    Predicted       Date
# 0  1    86       Q1  1734.827000  1715.011163 1986-03-31
# 1  2    86       Q2  2244.960999  2277.750192 1986-06-30
# 2  3    86       Q3  2533.804993  2194.873446 1986-09-30
# 3  4    86       Q4  2154.962997  1919.651866 1986-12-31
# 4  5    87       Q1  1547.818996  1703.261332 1987-03-31

# %%
# line plot - View for the entire dataset _ ASQ
viz2 = data2.loc[:,["Date","Sales","Predicted"]].melt("Date",var_name="predV/sTrue",value_name="Value")
sns.lineplot(data=viz2, x=viz2.Date, y=viz2.Value,hue="predV/sTrue",palette=["deeppink","lime"])
#There is certain variance in the initial years and final years
# Out:
# <Axes: xlabel='Date', ylabel='Value'>

# %%
#Line plot - Train V/s Test Plot
data2.Predicted.iloc[:35] = np.nan
data2.Sales.iloc[35:] = np.nan

viz3 = data2.loc[:,["Date","Sales","Predicted"]].melt("Date",var_name="predV/sTrue",value_name="Value")
sns.lineplot(data=viz3, x=viz3.Date, y=viz3.Value,hue="predV/sTrue",palette=["deeppink","lime"])
#There is large variance from true value
# Out:
# <ipython-input-41-44f20488ae7d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2.Predicted.iloc[:35] = np.nan
# <Axes: xlabel='Date', ylabel='Value'>

# %% [markdown]
# #### Pycaret ML Model based Methods
# - This is a low code library which is extremely good and fast
# - https://towardsdatascience.com/time-series-forecasting-with-pycaret-regression-module-237b703a0c63

# %%
#we have copied this data from previous case
data1.head()
# Out:
#    t years quarters        Sales
# 0  1    86       Q1  1734.827000
# 1  2    86       Q2  2244.960999
# 2  3    86       Q3  2533.804993
# 3  4    86       Q4  2154.962997
# 4  5    87       Q1  1547.818996

# %%
#Partition Series
train1 = data1.iloc[:35]
test1 = data1.iloc[35:]

# %%
#!pip install pycaret

# %%
# Import the PyCaret library and regression module
from pycaret.regression import setup

# Initialize setup
s = setup(data=train1,
          test_data=test1,
          target='Sales',
          fold_strategy='timeseries',
          numeric_features=['years', 't'],
          fold=3,
          transform_target=True,
          data_split_shuffle=False,  # Set data_split_shuffle to False
          fold_shuffle=False,        # Set fold_shuffle to False
          session_id=123)
# Out:
# <style type="text/css">
# #T_dc20f_row9_col1, #T_dc20f_row15_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_dc20f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dc20f_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_dc20f_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dc20f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dc20f_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_dc20f_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_dc20f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_dc20f_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_dc20f_row1_col1" class="data row1 col1" >Sales</td>
#     </tr>
#     <tr>
#       <th id="T_dc20f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_dc20f_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_dc20f_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_dc20f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_dc20f_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_dc20f_row3_col1" class="data row3 col1" >(42, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_dc20f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_dc20f_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_dc20f_row4_col1" class="data row4 col1" >(42, 15)</td>
#     </tr>
#     <tr>
#       <th id="T_dc20f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_dc20f_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_dc20f_row5_col1" class="data row5 col1" >(35, 15)</td>
#     </tr>
#     <tr>
#       <th id="T_dc20f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_dc20f_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_dc20f_row6_col1" class="data row6 col1" >(7, 15)</td>
#     </tr>
#     <tr>
#       <th id="T_dc20f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_dc20f_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_dc20f_row7_col1" class="data row7 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_dc20f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_dc20f_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_dc20f_row8_col1" class="data row8 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_dc20f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_dc20f_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_dc20f_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_dc20f_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_dc20f_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_dc20f_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_dc20f_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_dc20f_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_dc20f_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_dc20f_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_dc20f_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_dc20f_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_dc20f_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_dc20f_row13_col0" class="data row13 col0" >Maximum one-hot encoding</td>
#       <td id="T_dc20f_row13_col1" class="data row13 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_dc20f_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_dc20f_row14_col0" class="data row14 col0" >Encoding method</td>
#       <td id="T_dc20f_row14_col1" class="data row14 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_dc20f_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_dc20f_row15_col0" class="data row15 col0" >Transform target</td>
#       <td id="T_dc20f_row15_col1" class="data row15 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_dc20f_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_dc20f_row16_col0" class="data row16 col0" >Transform target method</td>
#       <td id="T_dc20f_row16_col1" class="data row16 col1" >yeo-johnson</td>
#     </tr>
#     <tr>
#       <th id="T_dc20f_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_dc20f_row17_col0" class="data row17 col0" >Fold Generator</td>
#       <td id="T_dc20f_row17_col1" class="data row17 col1" >TimeSeriesSplit</td>
#     </tr>
#     <tr>
#       <th id="T_dc20f_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_dc20f_row18_col0" class="data row18 col0" >Fold Number</td>
#       <td id="T_dc20f_row18_col1" class="data row18 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_dc20f_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_dc20f_row19_col0" class="data row19 col0" >CPU Jobs</td>
#       <td id="T_dc20f_row19_col1" class="data row19 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_dc20f_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_dc20f_row20_col0" class="data row20 col0" >Use GPU</td>
#       <td id="T_dc20f_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_dc20f_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_dc20f_row21_col0" class="data row21 col0" >Log Experiment</td>
#       <td id="T_dc20f_row21_col1" class="data row21 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_dc20f_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_dc20f_row22_col0" class="data row22 col0" >Experiment Name</td>
#       <td id="T_dc20f_row22_col1" class="data row22 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_dc20f_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_dc20f_row23_col0" class="data row23 col0" >USI</td>
#       <td id="T_dc20f_row23_col1" class="data row23 col1" >a76a</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Import the compare_models function from the PyCaret library
from pycaret.regression import compare_models

best = compare_models(sort = 'RMSE') #Super fast Library
#Best Values for Huber Regression RMSE = 350.2645
# Out:
# <style type="text/css">
# #T_1bd3e th {
#   text-align: left;
# }
# #T_1bd3e_row0_col0, #T_1bd3e_row0_col6, #T_1bd3e_row1_col0, #T_1bd3e_row1_col1, #T_1bd3e_row1_col2, #T_1bd3e_row1_col3, #T_1bd3e_row1_col4, #T_1bd3e_row1_col5, #T_1bd3e_row2_col0, #T_1bd3e_row2_col1, #T_1bd3e_row2_col2, #T_1bd3e_row2_col3, #T_1bd3e_row2_col4, #T_1bd3e_row2_col5, #T_1bd3e_row2_col6, #T_1bd3e_row3_col0, #T_1bd3e_row3_col1, #T_1bd3e_row3_col2, #T_1bd3e_row3_col3, #T_1bd3e_row3_col4, #T_1bd3e_row3_col5, #T_1bd3e_row3_col6, #T_1bd3e_row4_col0, #T_1bd3e_row4_col1, #T_1bd3e_row4_col2, #T_1bd3e_row4_col3, #T_1bd3e_row4_col4, #T_1bd3e_row4_col5, #T_1bd3e_row4_col6, #T_1bd3e_row5_col0, #T_1bd3e_row5_col1, #T_1bd3e_row5_col2, #T_1bd3e_row5_col3, #T_1bd3e_row5_col4, #T_1bd3e_row5_col5, #T_1bd3e_row5_col6, #T_1bd3e_row6_col0, #T_1bd3e_row6_col1, #T_1bd3e_row6_col2, #T_1bd3e_row6_col3, #T_1bd3e_row6_col4, #T_1bd3e_row6_col5, #T_1bd3e_row6_col6, #T_1bd3e_row7_col0, #T_1bd3e_row7_col1, #T_1bd3e_row7_col2, #T_1bd3e_row7_col3, #T_1bd3e_row7_col4, #T_1bd3e_row7_col5, #T_1bd3e_row7_col6, #T_1bd3e_row8_col0, #T_1bd3e_row8_col1, #T_1bd3e_row8_col2, #T_1bd3e_row8_col3, #T_1bd3e_row8_col4, #T_1bd3e_row8_col5, #T_1bd3e_row8_col6, #T_1bd3e_row9_col0, #T_1bd3e_row9_col1, #T_1bd3e_row9_col2, #T_1bd3e_row9_col3, #T_1bd3e_row9_col4, #T_1bd3e_row9_col5, #T_1bd3e_row9_col6, #T_1bd3e_row10_col0, #T_1bd3e_row10_col1, #T_1bd3e_row10_col2, #T_1bd3e_row10_col3, #T_1bd3e_row10_col4, #T_1bd3e_row10_col5, #T_1bd3e_row10_col6, #T_1bd3e_row11_col0, #T_1bd3e_row11_col1, #T_1bd3e_row11_col2, #T_1bd3e_row11_col3, #T_1bd3e_row11_col4, #T_1bd3e_row11_col5, #T_1bd3e_row11_col6, #T_1bd3e_row12_col0, #T_1bd3e_row12_col1, #T_1bd3e_row12_col2, #T_1bd3e_row12_col3, #T_1bd3e_row12_col4, #T_1bd3e_row12_col5, #T_1bd3e_row12_col6, #T_1bd3e_row13_col0, #T_1bd3e_row13_col1, #T_1bd3e_row13_col2, #T_1bd3e_row13_col3, #T_1bd3e_row13_col4, #T_1bd3e_row13_col5, #T_1bd3e_row13_col6, #T_1bd3e_row14_col0, #T_1bd3e_row14_col1, #T_1bd3e_row14_col2, #T_1bd3e_row14_col3, #T_1bd3e_row14_col4, #T_1bd3e_row14_col5, #T_1bd3e_row14_col6, #T_1bd3e_row15_col0, #T_1bd3e_row15_col1, #T_1bd3e_row15_col2, #T_1bd3e_row15_col3, #T_1bd3e_row15_col4, #T_1bd3e_row15_col5, #T_1bd3e_row15_col6, #T_1bd3e_row16_col0, #T_1bd3e_row16_col1, #T_1bd3e_row16_col2, #T_1bd3e_row16_col3, #T_1bd3e_row16_col4, #T_1bd3e_row16_col5, #T_1bd3e_row16_col6, #T_1bd3e_row17_col0, #T_1bd3e_row17_col1, #T_1bd3e_row17_col2, #T_1bd3e_row17_col3, #T_1bd3e_row17_col4, #T_1bd3e_row17_col5, #T_1bd3e_row17_col6, #T_1bd3e_row18_col0, #T_1bd3e_row18_col1, #T_1bd3e_row18_col2, #T_1bd3e_row18_col3, #T_1bd3e_row18_col4, #T_1bd3e_row18_col5, #T_1bd3e_row18_col6 {
#   text-align: left;
# }
# #T_1bd3e_row0_col1, #T_1bd3e_row0_col2, #T_1bd3e_row0_col3, #T_1bd3e_row0_col4, #T_1bd3e_row0_col5, #T_1bd3e_row1_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_1bd3e_row0_col7, #T_1bd3e_row1_col7, #T_1bd3e_row2_col7, #T_1bd3e_row3_col7, #T_1bd3e_row4_col7, #T_1bd3e_row5_col7, #T_1bd3e_row6_col7, #T_1bd3e_row7_col7, #T_1bd3e_row8_col7, #T_1bd3e_row9_col7, #T_1bd3e_row10_col7, #T_1bd3e_row11_col7, #T_1bd3e_row12_col7, #T_1bd3e_row13_col7, #T_1bd3e_row14_col7, #T_1bd3e_row15_col7, #T_1bd3e_row17_col7, #T_1bd3e_row18_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_1bd3e_row16_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_1bd3e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1bd3e_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_1bd3e_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_1bd3e_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_1bd3e_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_1bd3e_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_1bd3e_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_1bd3e_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_1bd3e_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1bd3e_level0_row0" class="row_heading level0 row0" >lr</th>
#       <td id="T_1bd3e_row0_col0" class="data row0 col0" >Linear Regression</td>
#       <td id="T_1bd3e_row0_col1" class="data row0 col1" >272.1685</td>
#       <td id="T_1bd3e_row0_col2" class="data row0 col2" >114513.2341</td>
#       <td id="T_1bd3e_row0_col3" class="data row0 col3" >319.8002</td>
#       <td id="T_1bd3e_row0_col4" class="data row0 col4" >0.1353</td>
#       <td id="T_1bd3e_row0_col5" class="data row0 col5" >0.1129</td>
#       <td id="T_1bd3e_row0_col6" class="data row0 col6" >0.0906</td>
#       <td id="T_1bd3e_row0_col7" class="data row0 col7" >4.3300</td>
#     </tr>
#     <tr>
#       <th id="T_1bd3e_level0_row1" class="row_heading level0 row1" >ridge</th>
#       <td id="T_1bd3e_row1_col0" class="data row1 col0" >Ridge Regression</td>
#       <td id="T_1bd3e_row1_col1" class="data row1 col1" >274.0768</td>
#       <td id="T_1bd3e_row1_col2" class="data row1 col2" >123315.9025</td>
#       <td id="T_1bd3e_row1_col3" class="data row1 col3" >332.4015</td>
#       <td id="T_1bd3e_row1_col4" class="data row1 col4" >0.0694</td>
#       <td id="T_1bd3e_row1_col5" class="data row1 col5" >0.1145</td>
#       <td id="T_1bd3e_row1_col6" class="data row1 col6" >0.0895</td>
#       <td id="T_1bd3e_row1_col7" class="data row1 col7" >0.2233</td>
#     </tr>
#     <tr>
#       <th id="T_1bd3e_level0_row2" class="row_heading level0 row2" >br</th>
#       <td id="T_1bd3e_row2_col0" class="data row2 col0" >Bayesian Ridge</td>
#       <td id="T_1bd3e_row2_col1" class="data row2 col1" >296.0097</td>
#       <td id="T_1bd3e_row2_col2" class="data row2 col2" >139682.1173</td>
#       <td id="T_1bd3e_row2_col3" class="data row2 col3" >358.6318</td>
#       <td id="T_1bd3e_row2_col4" class="data row2 col4" >-0.1381</td>
#       <td id="T_1bd3e_row2_col5" class="data row2 col5" >0.1282</td>
#       <td id="T_1bd3e_row2_col6" class="data row2 col6" >0.0988</td>
#       <td id="T_1bd3e_row2_col7" class="data row2 col7" >0.1767</td>
#     </tr>
#     <tr>
#       <th id="T_1bd3e_level0_row3" class="row_heading level0 row3" >lar</th>
#       <td id="T_1bd3e_row3_col0" class="data row3 col0" >Least Angle Regression</td>
#       <td id="T_1bd3e_row3_col1" class="data row3 col1" >348.7513</td>
#       <td id="T_1bd3e_row3_col2" class="data row3 col2" >209751.5956</td>
#       <td id="T_1bd3e_row3_col3" class="data row3 col3" >408.3886</td>
#       <td id="T_1bd3e_row3_col4" class="data row3 col4" >-0.6084</td>
#       <td id="T_1bd3e_row3_col5" class="data row3 col5" >0.1508</td>
#       <td id="T_1bd3e_row3_col6" class="data row3 col6" >0.1179</td>
#       <td id="T_1bd3e_row3_col7" class="data row3 col7" >0.3267</td>
#     </tr>
#     <tr>
#       <th id="T_1bd3e_level0_row4" class="row_heading level0 row4" >gbr</th>
#       <td id="T_1bd3e_row4_col0" class="data row4 col0" >Gradient Boosting Regressor</td>
#       <td id="T_1bd3e_row4_col1" class="data row4 col1" >304.7748</td>
#       <td id="T_1bd3e_row4_col2" class="data row4 col2" >172132.4113</td>
#       <td id="T_1bd3e_row4_col3" class="data row4 col3" >408.6706</td>
#       <td id="T_1bd3e_row4_col4" class="data row4 col4" >-0.1440</td>
#       <td id="T_1bd3e_row4_col5" class="data row4 col5" >0.1319</td>
#       <td id="T_1bd3e_row4_col6" class="data row4 col6" >0.0940</td>
#       <td id="T_1bd3e_row4_col7" class="data row4 col7" >0.2467</td>
#     </tr>
#     <tr>
#       <th id="T_1bd3e_level0_row5" class="row_heading level0 row5" >dt</th>
#       <td id="T_1bd3e_row5_col0" class="data row5 col0" >Decision Tree Regressor</td>
#       <td id="T_1bd3e_row5_col1" class="data row5 col1" >327.6432</td>
#       <td id="T_1bd3e_row5_col2" class="data row5 col2" >180214.1066</td>
#       <td id="T_1bd3e_row5_col3" class="data row5 col3" >415.5336</td>
#       <td id="T_1bd3e_row5_col4" class="data row5 col4" >-0.1591</td>
#       <td id="T_1bd3e_row5_col5" class=
# Processing:   0%|          | 0/81 [00:00<?, ?it/s]

# %%
# Import the predict_model function from the PyCaret library
from pycaret.regression import predict_model

prediction_holdout = predict_model(best)
# Out:
# <style type="text/css">
# </style>
# <table id="T_ed349" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ed349_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ed349_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_ed349_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_ed349_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_ed349_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_ed349_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_ed349_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ed349_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ed349_row0_col0" class="data row0 col0" >Linear Regression</td>
#       <td id="T_ed349_row0_col1" class="data row0 col1" >153.4883</td>
#       <td id="T_ed349_row0_col2" class="data row0 col2" >34619.1083</td>
#       <td id="T_ed349_row0_col3" class="data row0 col3" >186.0621</td>
#       <td id="T_ed349_row0_col4" class="data row0 col4" >0.8562</td>
#       <td id="T_ed349_row0_col5" class="data row0 col5" >0.0456</td>
#       <td id="T_ed349_row0_col6" class="data row0 col6" >0.0350</td>
#     </tr>
#   </tbody>
# </table>

# %%
# generate predictions on the original dataset
predictions = predict_model(best, data=data1)
predictions.head()
# Out:
# <style type="text/css">
# </style>
# <table id="T_2f2cc" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2f2cc_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_2f2cc_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_2f2cc_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_2f2cc_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_2f2cc_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_2f2cc_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_2f2cc_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2f2cc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2f2cc_row0_col0" class="data row0 col0" >Linear Regression</td>
#       <td id="T_2f2cc_row0_col1" class="data row0 col1" >79.7168</td>
#       <td id="T_2f2cc_row0_col2" class="data row0 col2" >11394.0532</td>
#       <td id="T_2f2cc_row0_col3" class="data row0 col3" >106.7429</td>
#       <td id="T_2f2cc_row0_col4" class="data row0 col4" >0.9878</td>
#       <td id="T_2f2cc_row0_col5" class="data row0 col5" >0.0358</td>
#       <td id="T_2f2cc_row0_col6" class="data row0 col6" >0.0274</td>
#     </tr>
#   </tbody>
# </table>
#    t years quarters        Sales  prediction_label
# 0  1    86       Q1  1734.827026       1849.220178
# 1  2    86       Q2  2244.960938       2311.297775
# 2  3    86       Q3  2533.804932       2296.219353
# 3  4    86       Q4  2154.962891       2146.982175
# 4  5    87       Q1  1547.818970       1650.415687

# %%
# add a date column in the dataset
predictions['Date'] = pd.date_range(start='1986-01-01', end = '1996-07-01', freq = 'Q')
data_ma = predictions.copy()
data4 =  predictions.copy()
predictions.head()
# Out:
#    t years quarters        Sales  prediction_label       Date
# 0  1    86       Q1  1734.827026       1849.220178 1986-03-31
# 1  2    86       Q2  2244.960938       2311.297775 1986-06-30
# 2  3    86       Q3  2533.804932       2296.219353 1986-09-30
# 3  4    86       Q4  2154.962891       2146.982175 1986-12-31
# 4  5    87       Q1  1547.818970       1650.415687 1987-03-31

# %%
# line plot - View for the entire dataset
viz1 = predictions.loc[:, ["Date", "Sales", "prediction_label"]].melt("Date", var_name="predV/sTrue", value_name="Value")
sns.lineplot(data=viz1, x="Date", y="Value", hue="predV/sTrue", palette=["aqua", "red"])
# Lesser Variance as compared to the previous case
# Out:
# <Axes: xlabel='Date', ylabel='Value'>

# %%
# line plot - View for the entire dataset

viz1 = predictions.loc[:,["Date","Sales"]].melt("Date",var_name="predV/sTrue",value_name="Value")
sns.lineplot(data=viz1, x=viz1.Date, y=viz1.Value,hue="predV/sTrue",palette=["aqua","red"])
#Lesser Variance as compared to previous case
# Out:
# <Axes: xlabel='Date', ylabel='Value'>

# %% [markdown]
# ### Data Driven Forecasting Techniques
#
# #### Moving Averages

# %%
#Make seperate dataset

data_ma = data_ma.set_index('Date')

#Simple Moving Average SMA
data_ma['3-month-SMA'] = data_ma['Sales'].rolling(window=3).mean()
data_ma['6-month-SMA'] = data_ma['Sales'].rolling(window=6).mean()
data_ma['12-month-SMA'] = data_ma['Sales'].rolling(window=12).mean()

# %%
sns.lineplot(data=data_ma[['3-month-SMA','6-month-SMA','12-month-SMA']],palette=["deeppink","lime","aqua"]) #SMA Plot
# Out:
# <Axes: xlabel='Date'>

# %%
#for 3-Months only since it will have the lowest SMA
data_ma['3-month-SMA']=data_ma['3-month-SMA'].fillna(0)
rmse_SMA_3Months = mean_squared_error(data_ma.Sales,data_ma['3-month-SMA'], squared=False)
pfm_data_bsd.update({'SMA-3Months':rmse_SMA_3Months})
rmse_SMA_3Months
# Out:
# 530.9743107228161

# %%
#Exponentially Weighted Moving Average EWMA
data_ma['EWMA3'] = data_ma['Sales'].ewm(span=3,adjust=True).mean() #3month Span

#Line Plot EWMA
sns.lineplot(data=data_ma[["Sales","EWMA3"]],palette=["deeppink","lime"]) #SMA Plot
# Out:
# <Axes: xlabel='Date'>

# %%
#for 3-Months only since it will have the lowest EWMA
data_ma['EWMA3'] =data_ma['EWMA3'] .fillna(0)
rmse_EWMA3 = mean_squared_error(data_ma.Sales,data_ma['EWMA3'] , squared=False)
pfm_data_bsd.update({'EWMA 3Months':rmse_EWMA3})
rmse_EWMA3 #This is a low value but it alone cannot be taken
# Out:
# 199.4860405567558

# %% [markdown]
# #### Smoothing Techniques

# %%
#Simple Exponential Method
ses_model = SimpleExpSmoothing(train["Sales"]).fit(smoothing_level=0.2)
pred_ses = ses_model.predict(start = test.index[0],end = test.index[-1])
rmse_SES = mean_squared_error(test.Sales,pred_ses, squared=False)
pfm_data_bsd.update({'SES':rmse_SES})
rmse_SES
# Out:
# 923.0344381080416

# %%
# Holt method
hw_model = Holt(train["Sales"]).fit(smoothing_level=0.8, smoothing_slope=0.2)
pred_hw = hw_model.predict(start = test.index[0],end = test.index[-1])
rmse_Holt = mean_squared_error(test.Sales,pred_hw, squared=False)
pfm_data_bsd.update({'Holt':rmse_Holt})
rmse_Holt
# Out:
# 797.1595562936291

# %%
#Holts winter exponential smoothing with additive seasonality and additive trend
hwe_model_add_add = ExponentialSmoothing(train["Sales"],seasonal="add",trend="add",seasonal_periods=12).fit() #add the trend to the model
pred_hwe_add_add = hwe_model_add_add.predict(start = test.index[0],end = test.index[-1])
rmse_hwe_add = mean_squared_error(test.Sales,pred_hwe_add_add, squared=False)
pfm_data_bsd.update({'HWE Add. Seas & Add. Trend':rmse_hwe_add})
rmse_hwe_add
# Out:
# 261.43577391391307

# %%
#Holts winter exponential smoothing with multiplicative seasonality and additive trend
hwe_model_mul_add = ExponentialSmoothing(train["Sales"],seasonal="mul",trend="add",seasonal_periods=12).fit()
pred_hwe_mul_add = hwe_model_mul_add.predict(start = test.index[0],end = test.index[-1])
rmse_hwe_mul = mean_squared_error(test.Sales,pred_hwe_mul_add, squared=False)
pfm_data_bsd.update({'HWE Mul. Seas & Add. Trend':rmse_hwe_mul})
rmse_hwe_mul #Very good value
# Out:
# 271.5135394681778

# %%
pfm_data_bsd
# Out:
# {'SMA-3Months': 530.9743107228161,
#  'EWMA 3Months': 199.4860405567558,
#  'SES': 923.0344381080416,
#  'Holt': 797.1595562936291,
#  'HWE Add. Seas & Add. Trend': 261.43577391391307,
#  'HWE Mul. Seas & Add. Trend': 271.5135394681778}

# %%
result_data_bsd = pd.DataFrame(pfm_data_bsd.items(),columns=['MODEL', 'RMSE'])
result_data_bsd.sort_values(by=['RMSE'])
#Lowest RSME values are for HWE Multiplicative Seasonality and Additive Trend
# Out:
#                         MODEL        RMSE
# 1                EWMA 3Months  199.486041
# 4  HWE Add. Seas & Add. Trend  261.435774
# 5  HWE Mul. Seas & Add. Trend  271.513539
# 0                 SMA-3Months  530.974311
# 3                        Holt  797.159556
# 2                         SES  923.034438

# %% [markdown]
# ###### Model Evaluation - HWE Multiplicative Seasonality and Additive Trend

# %%
hwe_mul_model = hwe_model_mul_add.predict(start = data.index[0],end = data.index[-1])
data3['predicted'] = hwe_mul_model
data3.head()
# Out:
#    t years quarters        Sales    predicted
# 0  1    86       Q1  1734.827000  1899.830596
# 1  2    86       Q2  2244.960999  2172.260312
# 2  3    86       Q3  2533.804993  2281.109320
# 3  4    86       Q4  2154.962997  2286.933848
# 4  5    87       Q1  1547.818996  1923.161962

# %%
# add a date column in the dataset
data3['Date'] = pd.date_range(start='1986-01-01', end = '1996-07-01', freq = 'Q')
data3.head()
# Out:
#    t years quarters        Sales    predicted       Date
# 0  1    86       Q1  1734.827000  1899.830596 1986-03-31
# 1  2    86       Q2  2244.960999  2172.260312 1986-06-30
# 2  3    86       Q3  2533.804993  2281.109320 1986-09-30
# 3  4    86       Q4  2154.962997  2286.933848 1986-12-31
# 4  5    87       Q1  1547.818996  1923.161962 1987-03-31

# %%
# line plot - View for the entire dataset _ ASQ
viz5 = data3.loc[:,["Date","Sales","predicted"]].melt("Date",var_name="predV/sTrue",value_name="Value")
sns.lineplot(data=viz5, x=viz5.Date, y=viz5.Value,hue="predV/sTrue",palette=["deeppink","lime"])
#THe model has the best RMSE value
# Out:
# <Axes: xlabel='Date', ylabel='Value'>

# %%
#Line plot - Train V/s Test Plot
data3.predicted.iloc[:35] = np.nan
data3.Sales.iloc[35:] = np.nan

viz6 = data3.loc[:,["Date","Sales","predicted"]].melt("Date",var_name="predV/sTrue",value_name="Value")
sns.lineplot(data=viz6, x=viz6.Date, y=viz6.Value,hue="predV/sTrue",palette=["deeppink","lime"])
# Out:
# <Axes: xlabel='Date', ylabel='Value'>

# %% [markdown]
# #### Auto Regression Models
# - Our data has both trend and Seasonality.
# - Very less chance for it to be stationary data.
# - We will perform AD-Fuller test to determine stationarity.
# - We will observe the ACF and PACF plots to determine suitable Lags.
# - After that, we will perform LL test on each model to determine best values
# ##### AD-Fuller stationarity test

# %%
from statsmodels.tsa.stattools import adfuller
def adf_test(series):
    result = adfuller(series.dropna())
    labels = ['ADF test statistic','p-value','# lags used','# observations']
    out = pd.Series(result[0:4],index=labels)
    #for key,val in result[4].items():
        #out[f'critical value ({key})']=val
    if result[1] <= 0.05:
        print("Reject the null hypothesis")
        print("Data is stationary")
    else:
        print("Fail to reject the null hypothesis")
        print("Data is non-stationary")

# %%
data4=data4.set_index('Date')
data4.head()
# Out:
#             t years quarters        Sales  prediction_label
# Date
# 1986-03-31  1    86       Q1  1734.827026       1849.220178
# 1986-06-30  2    86       Q2  2244.960938       2311.297775
# 1986-09-30  3    86       Q3  2533.804932       2296.219353
# 1986-12-31  4    86       Q4  2154.962891       2146.982175
# 1987-03-31  5    87       Q1  1547.818970       1650.415687

# %%
#AD- Fuller test
adf_test(data4[['Sales']]) #As expected, data is non stationary
#We might need to use SARIMA test in this case
# Out:
# Fail to reject the null hypothesis
# Data is non-stationary

# %%
#ACF and PACF Plots
tsa_plots.plot_acf(viz,lags=12)
#Autocorrelation Factor >> uptill 6 we have good corr() above +-2 SE [Standard Error]
tsa_plots.plot_pacf(viz,lags=12)
#Partial Autocorrelation Factor >> only 9 and 11 show some good corr() +-2 SE [Standard Error]
plt.show()

# %%
# We will run a auto arima to determine the ARIME orders
from pmdarima import auto_arima # for determining ARIMA orders

# %%
stepwise_fit = auto_arima(data4.Sales, start_p=0, start_q=0,
                          max_p=12, max_q=12, m=12,
                          seasonal=False,
                          d=None, trace=True,
                          error_action='ignore',   # we don't want to know if an order does not work
                          suppress_warnings=True,  # we don't want convergence warnings
                          stepwise=True)           # set to stepwise

stepwise_fit.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=617.615, Time=0.03 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=619.036, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=607.723, Time=0.23 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=617.215, Time=0.04 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=608.949, Time=0.57 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=606.079, Time=0.17 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=607.920, Time=0.22 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.27 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=596.966, Time=0.31 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=578.516, Time=0.37 sec
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=579.745, Time=0.32 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=557.379, Time=0.42 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=559.112, Time=0.29 sec
#  ARIMA(4,1,3)(0,0,0)[0] intercept   : AIC=563.430, Time=0.42 sec
#  ARIMA(3,1,4)(0,0,0)[0] intercept   : AIC=inf, Time=0.46 sec
#  ARIMA(2,1,4)(0,0,0)[0] intercept   : AIC=582.017, Time=0.39 sec
#  ARIMA(4,1,2)(0,0,0)[0] intercept   : AIC=558.674, Time=0.40 sec
#  ARIMA(4,1,4)(0,0,0)[0] intercept   : AIC=569.821, Time=0.55 sec
#  ARIMA(3,1,3)(0,0,0)[0]             : AIC=576.375, Time=0.36 sec
#
# Best model:  ARIMA(3,1,3)(0,0,0)[0] intercept
# Total fit time: 5.881 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   42
# Model:               SARIMAX(3, 1, 3)   Log Likelihood                -270.690
# Date:                Thu, 04 Apr 2024   AIC                            557.379
# Time:                        16:13:47   BIC                            571.088
# Sample:                    03-31-1986   HQIC                           562.371
#                          - 06-30-1996
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept    281.4752     70.864      3.972      0.000     142.585     420.366
# ar.L1         -1.0106      0.052    -19.467      0.000      -1.112      -0.909
# ar.L2         -1.0040      0.059    -16.952      0.000      -1.120      -0.888
# ar.L3         -0.9892      0.019    -51.721      0.000      -1.027      -0.952
# ma.L1          0.9384      0.211      4.455      0.000       0.525       1.351
# ma.L2          0.5186      0.277      1.870      0.061      -0.025       1.062
# ma.L3          0.4554      0.170      2.673      0.008       0.122       0.789
# sigma2      2.021e+04   5285.238      3.824      0.000    9852.447    3.06e+04
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):                 7.28
# Prob(Q):                              0.92   Prob(JB):                         0.03
# Heteroskedasticity (H):               0.56   Skew:                            -0.83
# Prob(H) (two-sided):                  0.29   Kurtosis:                         4.24
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
from statsmodels.tsa.arima.model import ARIMA

# Fitting the ARIMA model
model_arima = ARIMA(train['Sales'], order=(4, 1, 0))
results = model_arima.fit()

# Displaying the summary of the model
print(results.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Sales   No. Observations:                   35
# Model:                 ARIMA(4, 1, 0)   Log Likelihood                -228.563
# Date:                Thu, 04 Apr 2024   AIC                            467.125
# Time:                        16:13:59   BIC                            474.757
# Sample:                             0   HQIC                           469.728
#                                  - 35
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.0766      0.089     -0.858      0.391      -0.252       0.098
# ar.L2         -0.1251      0.112     -1.115      0.265      -0.345       0.095
# ar.L3         -0.0425      0.113     -0.377      0.706      -0.263       0.178
# ar.L4          0.8201      0.110      7.477      0.000       0.605       1.035
# sigma2      3.184e+04   8193.469      3.887      0.000    1.58e+04    4.79e+04
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):                 0.13
# Prob(Q):                              0.92   Prob(JB):                         0.94
# Heteroskedasticity (H):               0.69   Skew:                            -0.15
# Prob(H) (two-sided):                  0.55   Kurtosis:                         2.99
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
pred_arima = results.predict(start=35, end=len(data4)-1, dynamic=False, typ='levels')

# %%
#RMSE score of ARIMA
rmse_arima= mean_squared_error(test.Sales,pred_arima, squared=False)
rmse_arima #This value is okay but we will not use it sine we have much better models
# Out:
# 187.76196298160215

# %% [markdown]
# ## Evaluate and Compare Performance
# - Best model we have got so far is the Huber Regressor from PyCaret
# - We will build our final model based on this one

# %% [markdown]
# ## Implementing Forecasting Model

# %%
#Holts winter exponential smoothing with multiplicative seasonality and additive trend
final_model = ExponentialSmoothing(data_fnl["Sales"],seasonal="mul",trend="add",seasonal_periods=12).fit()
pred_final = final_model.predict(start = data.index[0],end = data.index[-1])

#Getting RMSE Score
rmse_final = mean_squared_error(data.Sales,pred_final, squared=False)
rmse_final #This score is good
# Out:
# 129.75975108785772

# %%
data_fnl.head()
# Out:
#    t years quarters        Sales
# 0  1    86       Q1  1734.827000
# 1  2    86       Q2  2244.960999
# 2  3    86       Q3  2533.804993
# 3  4    86       Q4  2154.962997
# 4  5    87       Q1  1547.818996

# %%
data_fnl['final_pred']=pred_final
data_fnl.head()
# Out:
#    t years quarters        Sales   final_pred
# 0  1    86       Q1  1734.827000  1845.217484
# 1  2    86       Q2  2244.960999  2213.241431
# 2  3    86       Q3  2533.804993  2230.776854
# 3  4    86       Q4  2154.962997  2269.675669
# 4  5    87       Q1  1547.818996  2033.219059

# %%
data_fnl['Date'] = pd.date_range(start='1986-01-01', end = '1996-07-01', freq = 'Q')
data_fnl.head()
# Out:
#    t years quarters        Sales   final_pred       Date
# 0  1    86       Q1  1734.827000  1845.217484 1986-03-31
# 1  2    86       Q2  2244.960999  2213.241431 1986-06-30
# 2  3    86       Q3  2533.804993  2230.776854 1986-09-30
# 3  4    86       Q4  2154.962997  2269.675669 1986-12-31
# 4  5    87       Q1  1547.818996  2033.219059 1987-03-31

# %%
# line plot - View for the entire dataset FInal Model
viz8 = data_fnl.loc[:,["Date","Sales","final_pred"]].melt("Date",var_name="predV/sTrue",value_name="Value")
sns.lineplot(data=viz8, x=viz8.Date, y=viz8.Value,hue="predV/sTrue",palette=["deeppink","lime"])
#Good model but since we have limited dataset, values are less to improve accuracy
# Out:
# <Axes: xlabel='Date', ylabel='Value'>

# %%
#Forecasting the future
future = pd.DataFrame(final_model.forecast(8)).reset_index()
future.rename(columns={'index':'t',0:'Forecast'},inplace=True)
future.head()
# Out:
#     t     Forecast
# 0  42  5012.147440
# 1  43  4645.260903
# 2  44  4490.053377
# 3  45  5638.551712
# 4  46  5671.720685

# %%
#Creating Forecast dataset
forecast_df= pd.concat([data_fnl,future], axis=0)
forecast_df.drop('Date',axis=1)
forecast_df['Date']=pd.date_range(start='1986-01-01', end = '1998-09-01', freq = 'Q')
forecast_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50 entries, 0 to 7
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   t           50 non-null     int64
#  1   years       42 non-null     object
#  2   quarters    42 non-null     object
#  3   Sales       42 non-null     float64
#  4   final_pred  42 non-null     float64
#  5   Date        50 non-null     datetime64[ns]
#  6   Forecast    8 non-null      float64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(2)
# memory usage: 3.1+ KB

# %%
#Future Forecast

viz9 = forecast_df.loc[:,["Date","Sales","Forecast"]].melt("Date",var_name="predV/sTrue",value_name="Value")
sns.lineplot(data=viz9, x=viz9.Date, y=viz9.Value,hue="predV/sTrue",palette=["deeppink","lime"])
#Best internal forecast so far
# Out:
# <Axes: xlabel='Date', ylabel='Value'>

# %% [markdown]
# ## Conclusion
# - We have explored all the possible forecasting techniques.
# - We have built our final model from HWE Multiplicative Seasonality and Additive Trend
# - Forecasting for eight quarters has been plotted.
# - If RMSE was not the metric of usage, We could have gone for Gradient Boosting in PyCaret
